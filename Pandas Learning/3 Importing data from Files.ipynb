# %% [markdown]
# # Importing CSV Files with pd.read_csv()

# %%
import pandas as pd

# %%
pd.read_csv("titanic.csv")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.0      1      0    7.2500        S  NaN
# 1           1       1  female  38.0      1      0   71.2833        C    C
# 2           1       3  female  26.0      0      0    7.9250        S  NaN
# 3           1       1  female  35.0      1      0   53.1000        S    C
# 4           0       3    male  35.0      0      0    8.0500        S  NaN
# 5           0       3    male   NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.0      0      0   51.8625        S    E
# 7           0       3    male   2.0      3      1   21.0750        S  NaN
# 8           1       3  female  27.0      0      2   11.1333        S  NaN
# 9           1       2  female  14.0      1      0   30.0708        C  NaN
# 10          1       3  female   4.0      1      1   16.7000        S    G
# 11          1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
#Specifying column to be used as index

pd.read_csv("titanic.csv", index_col= "pclass")
# Out:
#         survived     sex   age  sibsp  parch      fare embarked deck
# pclass
# 3              0    male  22.0      1      0    7.2500        S  NaN
# 1              1  female  38.0      1      0   71.2833        C    C
# 3              1  female  26.0      0      0    7.9250        S  NaN
# 1              1  female  35.0      1      0   53.1000        S    C
# 3              0    male  35.0      0      0    8.0500        S  NaN
# 3              0    male   NaN      0      0    8.4583        Q  NaN
# 1              0    male  54.0      0      0   51.8625        S    E
# 3              0    male   2.0      3      1   21.0750        S  NaN
# 3              1  female  27.0      0      2   11.1333        S  NaN
# 2              1  female  14.0      1      0   30.0708        C  NaN
# 3              1  female   4.0      1      1   16.7000        S    G
# 1              1  female  58.0      0      0   26.5500        S    C
# ...

# %%
pd.read_csv("titanic.csv", header = None)
# Out:
#             0       1       2     3      4      5        6         7     8
# 0    survived  pclass     sex   age  sibsp  parch     fare  embarked  deck
# 1           0       3    male  22.0      1      0     7.25         S   NaN
# 2           1       1  female  38.0      1      0  71.2833         C     C
# 3           1       3  female  26.0      0      0    7.925         S   NaN
# 4           1       1  female  35.0      1      0     53.1         S     C
# 5           0       3    male  35.0      0      0     8.05         S   NaN
# 6           0       3    male   NaN      0      0   8.4583         Q   NaN
# 7           0       1    male  54.0      0      0  51.8625         S     E
# 8           0       3    male   2.0      3      1   21.075         S   NaN
# 9           1       3  female  27.0      0      2  11.1333         S   NaN
# 10          1       2  female  14.0      1      0  30.0708         C   NaN
# ...

# %%
pd.read_csv("titanic.csv", header = None, names= ["Alive", "Class", "Gender", "Age", "SipSp", "ParCh", "Fare", "Emb", "Deck"])
# Out:
#         Alive   Class  Gender   Age  SipSp  ParCh     Fare       Emb  Deck
# 0    survived  pclass     sex   age  sibsp  parch     fare  embarked  deck
# 1           0       3    male  22.0      1      0     7.25         S   NaN
# 2           1       1  female  38.0      1      0  71.2833         C     C
# 3           1       3  female  26.0      0      0    7.925         S   NaN
# 4           1       1  female  35.0      1      0     53.1         S     C
# 5           0       3    male  35.0      0      0     8.05         S   NaN
# 6           0       3    male   NaN      0      0   8.4583         Q   NaN
# 7           0       1    male  54.0      0      0  51.8625         S     E
# 8           0       3    male   2.0      3      1   21.075         S   NaN
# 9           1       3  female  27.0      0      2  11.1333         S   NaN
# 10          1       2  female  14.0      1      0  30.0708         C   NaN
# ...

# %%
pd.read_csv("titanic.csv", header = 0, names= ["Alive", "Class", "Gender", "Age", "SipSp", "ParCh", "Fare", "Emb", "Deck"])
# Out:
#      Alive  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0    7.2500   S  NaN
# 1        1      1  female  38.0      1      0   71.2833   C    C
# 2        1      3  female  26.0      0      0    7.9250   S  NaN
# 3        1      1  female  35.0      1      0   53.1000   S    C
# 4        0      3    male  35.0      0      0    8.0500   S  NaN
# 5        0      3    male   NaN      0      0    8.4583   Q  NaN
# 6        0      1    male  54.0      0      0   51.8625   S    E
# 7        0      3    male   2.0      3      1   21.0750   S  NaN
# 8        1      3  female  27.0      0      2   11.1333   S  NaN
# 9        1      2  female  14.0      1      0   30.0708   C  NaN
# 10       1      3  female   4.0      1      1   16.7000   S    G
# 11       1      1  female  58.0      0      0   26.5500   S    C
# 12       0      3    male  20.0      0      0    8.0500   S  NaN
# ...

# %%
pd.read_csv("titanic.csv", header = 0)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.0      1      0    7.2500        S  NaN
# 1           1       1  female  38.0      1      0   71.2833        C    C
# 2           1       3  female  26.0      0      0    7.9250        S  NaN
# 3           1       1  female  35.0      1      0   53.1000        S    C
# 4           0       3    male  35.0      0      0    8.0500        S  NaN
# 5           0       3    male   NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.0      0      0   51.8625        S    E
# 7           0       3    male   2.0      3      1   21.0750        S  NaN
# 8           1       3  female  27.0      0      2   11.1333        S  NaN
# 9           1       2  female  14.0      1      0   30.0708        C  NaN
# 10          1       3  female   4.0      1      1   16.7000        S    G
# 11          1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
pd.read_csv("titanic.csv", usecols=["pclass", "survived", "sex", "age"])
# Out:
#      survived  pclass     sex   age
# 0           0       3    male  22.0
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 4           0       3    male  35.0
# 5           0       3    male   NaN
# 6           0       1    male  54.0
# 7           0       3    male   2.0
# 8           1       3  female  27.0
# 9           1       2  female  14.0
# 10          1       3  female   4.0
# 11          1       1  female  58.0
# 12          0       3    male  20.0
# 13          0       3    male  39.0
# 14          0       3  female  14.0
# 15          1       2  female  55.0
# 16          0       3    male   2.0
# 17          1       2    male   NaN
# 18          0       3  female  31.0
# 19          1       3  female   NaN
# 20          0       2    male  35.0
# 21          1       2    male  34.0
# 22          1       3  female  15.0
# 23          1       1    male  28.0
# 24          0       3  female   8.0
# ...

# %%
titanic = pd.read_csv("titanic.csv", index_col= "pclass", usecols= ["pclass", "survived", "sex", "age"])

# %%
titanic.head()
# Out:
#         survived     sex   age
# pclass
# 3              0    male  22.0
# 1              1  female  38.0
# 3              1  female  26.0
# 1              1  female  35.0
# 3              0    male  35.0

# %%
titanic = pd.read_csv("titanic.csv", index_col= 0, usecols= ["pclass", "survived", "sex", "age"])
titanic.head()
# Out:
#           pclass     sex   age
# survived
# 0              3    male  22.0
# 1              1  female  38.0
# 1              3  female  26.0
# 1              1  female  35.0
# 0              3    male  35.0

# %%
titanic.columns = ["Alive", "Gender", "Age"]

# %%
titanic.index.name = "Class"

# %%
titanic.head()
# Out:
#        Alive  Gender   Age
# Class
# 3          0    male  22.0
# 1          1  female  38.0
# 3          1  female  26.0
# 1          1  female  35.0
# 3          0    male  35.0

# %% [markdown]
# ## Importing messy CSV Files

# %%
pd.read_csv("titanic_raw.csv")
# Out:
#                                                    This       is       the  \
# It   contains  all       passengers  that          were   aboard       the
# the  tragic    disaster  occured     in             the     year        19
# 0   0         3         male        22.0              1        0     $7.25
# 1   1         1         female      38.0              1        0  $71.2833
# 2   1         3         female      26.0              0        0    $7.925
# 3   1         1         female      35.0              1        0     $53.1
# 4   0         3         male        35.0              0        0     $8.05
# 5   0         3         male        Missing Data      0        0   $8.4583
# 6   0         1         male        54.0              0        0  $51.8625
# 7   0         3         male        2.0               3        1   $21.075
# 8   1         3         female      27.0              0        2  $11.1333
# ...

# %%
col_names = ["Survived", "Class", "Gender", "Age", "SipSp", "ParCh", "Fare", "Emb", "Deck"]

# %%
titanic = pd.read_csv("titanic_raw.csv", skiprows= 3, skipfooter= 2, header = None, names = col_names)
titanic.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
# While inserting index become as a new column
titanic.to_csv("titanic_imp.csv", index=False)

# %%
pd.read_csv("titanic_imp.csv")
# Out:
#     Survived  Class  Gender           Age  SipSp  ParCh      Fare Emb Deck
# 0          0      3    male          22.0      1      0     $7.25   S  NaN
# 1          1      1  female          38.0      1      0  $71.2833   C    C
# 2          1      3  female          26.0      0      0    $7.925   S  NaN
# 3          1      1  female          35.0      1      0     $53.1   S    C
# 4          0      3    male          35.0      0      0     $8.05   S  NaN
# 5          0      3    male  Missing Data      0      0   $8.4583   Q  NaN
# 6          0      1    male          54.0      0      0  $51.8625   S    E
# 7          0      3    male           2.0      3      1   $21.075   S  NaN
# 8          1      3  female          27.0      0      2  $11.1333   S  NaN
# 9          1      2  female          14.0      1      0  $30.0708   C  NaN
# 10         1      3  female           4.0      1      1     $16.7   S    G
# ...

# %%
titanic_try = pd.read_csv("titanic.csv" , header=0 ,index_col = 'sex')
titanic_try.head()
# Out:
#         survived  pclass   age  sibsp  parch     fare embarked deck
# sex
# male           0       3  22.0      1      0   7.2500        S  NaN
# female         1       1  38.0      1      0  71.2833        C    C
# female         1       3  26.0      0      0   7.9250        S  NaN
# female         1       1  35.0      1      0  53.1000        S    C
# male           0       3  35.0      0      0   8.0500        S  NaN

# %%
# While inserting index become as a new column
titanic.to_csv("titanic_try.csv")

# %%
pd.read_csv("titanic_try.csv")
# Out:
#      Unnamed: 0 Survived  Class  Gender           Age  SipSp  ParCh      Fare  \
# 0             0        0      3    male          22.0      1      0     $7.25
# 1             1        1      1  female          38.0      1      0  $71.2833
# 2             2        1      3  female          26.0      0      0    $7.925
# 3             3        1      1  female          35.0      1      0     $53.1
# 4             4        0      3    male          35.0      0      0     $8.05
# 5             5        0      3    male  Missing Data      0      0   $8.4583
# 6             6        0      1    male          54.0      0      0  $51.8625
# 7             7        0      3    male           2.0      3      1   $21.075
# 8             8        1      3  female          27.0      0      2  $11.1333
# 9             9        1      2  female          14.0      1      0  $30.0708
# 10           10        1      3  female           4.0      1      1     $16.7
# ...

# %% [markdown]
# # Importing from Excel Files with pd.read_excel()

# %%
import pandas as pd

# %%
sales = pd.read_excel("sales.xls", index_col = 0)
sales.head()
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0)
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0, names = ["Name", "Loc_City", "Loc_Country", "Revenue", "Add_Comp"])
# Out:
#         Loc_City Loc_Country  Revenue  Add_Comp
# Name
# Mike    New York         USA       25      2.50
# Jim       Boston         USA       43      4.30
# Steven    London          UK       76      7.60
# Joe       Madrid       Spain       12      1.80
# Tom        Paris      France       89     13.35

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = "A:C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = "C:E")
# Out:
#          Sales  Bonus
# Country
# USA         25   2.50
# USA         43   4.30
# UK          76   7.60
# Spain       12   1.80
# France      89  13.35

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = "A, C:E")
# Out:
#        Country  Sales  Bonus
# Mike       USA     25   2.50
# Jim        USA     43   4.30
# Steven      UK     76   7.60
# Joe      Spain     12   1.80
# Tom     France     89  13.35

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = ":C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
# Cant take till the very Last
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = "C:")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-f28ed5aa0c3b> in <module>
# ----> 1 pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = "B:")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = [0,3,4])
# Out:
#         Sales  Bonus
# Mike       25   2.50
# Jim        43   4.30
# Steven     76   7.60
# Joe        12   1.80
# Tom        89  13.35

# %%
#Start till the specified column (2)
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = 2)
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel("sales.xls", index_col = 0, header = 0, usecols = ["City", "Sales"])
# Out:
#           Sales
# City
# New York     25
# Boston       43
# London       76
# Madrid       12
# Paris        89

# %% [markdown]
# ## Customizing import with pd.read_excel()

# %%
pd.read_excel("summer_raw.xls")
# Out:
#   Unnamed: 0      City Country  Sales  Bonus
# 0       Mike  New York     USA     25    2.5
# 1        Jim    Boston     USA     43    4.3
# 2     Steven    London      UK     76    7.6
# 3        Joe    Madrid   Spain     12    1.8
# 4        Tom     Paris  France     89   13.4

# %%
pd.read_excel("summer_raw.xls", sheet_name = 1)
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN         NaN         NaN        NaN        NaN        NaN
# 1             NaN         NaN         NaN       Year       City      Sport
# 2             NaN         NaN         0.0       1896     Athens   Aquatics
# 3             NaN         NaN         1.0       1896     Athens   Aquatics
# 4             NaN         NaN         2.0       1896     Athens   Aquatics
# 5             NaN         NaN         3.0       1896     Athens   Aquatics
# 6             NaN         NaN         4.0       1896     Athens   Aquatics
# 7             NaN         NaN         5.0       1896     Athens   Aquatics
# 8             NaN         NaN         6.0       1896     Athens   Aquatics
# 9             NaN         NaN         7.0       1896     Athens   Aquatics
# 10            NaN         NaN         8.0       1896     Athens   Aquatics
# ...

# %%
pd.read_excel("summer_raw.xls", sheet_name = "summer", skiprows= [0,1])
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Year    City      Sport  \
# 0             NaN         NaN           0  1896  Athens   Aquatics
# 1             NaN         NaN           1  1896  Athens   Aquatics
# 2             NaN         NaN           2  1896  Athens   Aquatics
# 3             NaN         NaN           3  1896  Athens   Aquatics
# 4             NaN         NaN           4  1896  Athens   Aquatics
# 5             NaN         NaN           5  1896  Athens   Aquatics
# 6             NaN         NaN           6  1896  Athens   Aquatics
# 7             NaN         NaN           7  1896  Athens   Aquatics
# 8             NaN         NaN           8  1896  Athens   Aquatics
# 9             NaN         NaN           9  1896  Athens   Aquatics
# 10            NaN         NaN          10  1896  Athens   Aquatics
# 11            NaN         NaN          11  1896  Athens  Athletics
# 12            NaN         NaN          12  1896  Athens  Athletics
# ...

# %%
summer = pd.read_excel("summer_raw.xls", sheet_name = "summer", skiprows= 2, usecols= "D:L")
summer.head()
# Out:
#    Year    City     Sport Discipline          Athlete Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event       Medal
# 0              100M Freestyle  Gold Medal
# 1              100M Freestyle      Silver
# 2  100M Freestyle For Sailors      Bronze
# 3  100M Freestyle For Sailors  Gold Medal
# 4  100M Freestyle For Sailors      Silver

# %%
summer.to_excel("summer_imp.xls")

# %% [markdown]
# ## Importing Data from the Web  with pd.read_html()

# %%
url = "https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table"

# %%
pd.read_html(url)[1]
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
wik_1976 = pd.read_html(url)[0]

# %%
wik_1976.head()

# %%
url2 ="https://en.wikipedia.org/wiki/1996_Summer_Olympics_medal_table"

# %%
pd.read_html(url2)[1]
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
wik_1996 = pd.read_html(url2)[1]

# %%
wik_1996.head()
